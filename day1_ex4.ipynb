# %% [markdown]
# <a href="https://colab.research.google.com/github/niknovikov19/netpyne_course_2021/blob/main/day1_ex4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install neuron
# Out:
# Requirement already satisfied: neuron in /usr/local/lib/python3.7/dist-packages (8.0.0)
# Requirement already satisfied: numpy>=1.9.3 in /usr/local/lib/python3.7/dist-packages (from neuron) (1.19.5)

# %%
from neuron import h
from neuron.units import ms, mV, um, cm
import matplotlib.pyplot as plt
import plotly
h.load_file('stdrun.hoc')
h.load_file('import3d.hoc')
# Out:
# 1.0

# %%
# !wget 'http://neuromorpho.org/dableFiles/amaral/CNG%20version/c91662.CNG.swc'
# Out:
# --2021-05-17 22:43:25--  http://neuromorpho.org/dableFiles/amaral/CNG%20version/c91662.CNG.swc
# Resolving neuromorpho.org (neuromorpho.org)... 129.174.130.34
# Connecting to neuromorpho.org (neuromorpho.org)|129.174.130.34|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 54984 (54K) [text/plain]
# Saving to: ‘c91662.CNG.swc.1’
#
# c91662.CNG.swc.1    100%[===================>]  53.70K  --.-KB/s    in 0.06s
#
# 2021-05-17 22:43:26 (938 KB/s) - ‘c91662.CNG.swc.1’ saved [54984/54984]

# %%
# !pwd
# Out:
# /content

# %%
class Pyramidal:
  def __init__(self, gid):
    self._gid = gid
    self._load_morphology()
  def __repr__(self):
    return f'Pyramidal[{self._gid}]'
  def _load_morphology(self):
    cell = h.Import3d_SWC_read()
    cell.input('c91662.CNG.swc.1')
    i3d = h.Import3d_GUI(cell, False)
    i3d.instantiate(self)

# %%
pyr1 = Pyramidal(0)

# %%
dir(pyr1)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_gid',
#  '_load_morphology',
#  'all',
#  'apic',
#  'axon',
#  'dend',
#  'soma']

# %%
len(pyr1.apic)
# Out:
# 134

# %%
ps = h.PlotShape(False)
ps.plot(plotly).show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="cb2cb8a1-c692-43dd-9771-61dd62511b53" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("cb2cb8a1-c692-43dd-9771-61dd62511b53")) {
#                     Plotly.newPlot(
#                         'cb2cb8a1-c692-43dd-9771-61dd62511b53',
#                         [{"hovertemplate": "<__main__.Pyramidal object at 0x7f9866ee3c90>.soma[0](0.5)<br>-65.000", "line": {"color": "#00ffff", "width": 2}, "mode": "lines", "name": "", "type": "scatter3d", "uid": "7a487e12-7cc5-414b-bc1e-1d1557ca7451", "x": [-8.86769962310791, 0.0, 8.86769962310791], "y": [0.0, 0.0, 0.0], "z": [0.0, 0.0, 0.0]}, {"hovertemplate": "<__main__.Pyramidal object at 0x7f9866ee3c90>.axon[0](0.5)<br>-65.000", "line": {"color": "#00ffff", "width": 2}, "mode": "lines", "name": "", "type": "scatter3d", "uid": "08120c98-33e3-4162-9c0c-9a57c9a55b4c", "x": [-5.329999923706055, -6.360000133514404, -6.75, -9.050000190734863, -7.820000171661377, -6.989999771118164, -11.470000267028809, -13.550000190734863, -18.540000915527344, -23.600000381469727, -25.0, -31.829999923706055, -34.29999923706055, -38.63999938964844, -42.599998474121094, -49.31999969482422, -58.91999816894531, -66.37